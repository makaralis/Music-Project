# %%
import requests
import html
import urllib.request
import urllib.error
import urllib.parse
from bs4 import BeautifulSoup as bs

import time
import os
import seaborn as sns
import pandas as pd
import scipy as sc
import numpy as np

import statsmodels.formula.api as sm

import matplotlib.pyplot as plt 
plt.style.use('ggplot')
# %matplotlib inline  
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ## Important Note:<br>
# ## If you want to build the DataFrame by your own and download the relevant files to achive this task then begin from here.<br>
# ## If you want to run the code when you already using existed DataFrame and downloaded files, Please skip to Phase 2 - Learning Algorithm & Performance Evaluation

# %% [markdown]
# # Phase 1 - Data Acquisition & Data Cleaning & Data Vectorization

# %%
#creating the list of Billboard urls
billboardUrls = []
years = ["2016","2017","2018"]
for i in years:
    url = 'https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_' + str(i)
    billboardUrls.append(url)   
print(billboardUrls)
# Out:
# ['https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2016', 'https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2017', 'https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2018']

# %%
#saving 3 billboard pages on the laptop   
def save_html(url):
    response1 = urllib.request.urlopen(url)
    webContent = response1.read()
    
    f = open('./data/top_100/'+url[url.index('Billboard'):]+'.html', 'wb') #if there is no such file the function open creates it 
    f.write(webContent)
    f.close

for url in billboardUrls:
    save_html(url)

# %%
#creating lists of lists for each year
songs={"2016": [],"2017": [], "2018":[]}
artists={"2016": [],"2017": [], "2018":[]}

for i in range(6,9):
    content = open("./data/top_100/Billboard_Year-End_Hot_100_singles_of_201"+str(i)+".html", encoding='utf-8')
    soup_html = bs(content, "html.parser")

    titles=soup_html.findAll('td')
    for title in titles[0:len(titles)-5:2]:
        songs["201{}".format(i)].append(title.text.replace('\n','').replace(',','').replace('(','').replace(')','')
                                        .replace('é','e').replace('?','').replace('"','').replace("!",""))
    for title in titles[1:len(titles)-5:2]:    
        artists["201{}".format(i)].append(title.text.replace('é','e').replace('í','i').replace('\n','')
                                          .replace('+','').replace('.',''))
 

print(artists["2018"][80]) 
print(songs["2018"][80])
# Out:
# Nio Garcia, Darell and Casper Mágico featuring Bad Bunny, Nicky Jam and Ozuna
# Te Bote

# %%
#creating a dictionary of a df for each year for name of the song & name of artist
songs_df={"2016_df": pd.DataFrame(),"2017_df": pd.DataFrame(), "2018_df":pd.DataFrame()}
for key, value in songs_df.items():
    songs_df[key]['Title'] = songs["2016"]
    songs_df[key]['Artist'] = artists["2016"]
songs_df["2016_df"].head()
# Out:
#            Title                           Artist
# 0  Love Yourself                    Justin Bieber
# 1          Sorry                    Justin Bieber
# 2      One Dance  Drake featuring Wizkid and Kyla
# 3           Work          Rihanna featuring Drake
# 4   Stressed Out                Twenty One Pilots

# %%
#creating a dictionary of lists which contain url for each song of top 100 for each year in wikipedia
songs_urls_wiki={"2016": [],"2017": [], "2018": []}

for i in range(6,9):
    content = open("./data/top_100/Billboard_Year-End_Hot_100_singles_of_201"+str(i)+".html", encoding='utf-8')
    soup_html = bs(content, "html.parser")

    titles=soup_html.findAll('td')
    for title in titles[0:len(titles)-5:2]:
        name='https://en.wikipedia.org'+str(title)[str(title).index('href')+6:str(title).index('title')-2]
#   'https://en.wikipedia.org/wiki/Bartier_Cardi',
#   'https://en.wikipedia.org/wiki/God_Is_a_Woman',
#   'https://en.wikipedia.org/wiki/Big_Bank',
#   'https://en.wikipedia.org/wiki/Sorry_Not_Sorry_(Demi_Lovato_song)',
#   'https://en.wikipedia.org/wiki/How_Long_(Charlie_Puth_song)',
#   'https://en.wikipedia.org/wiki/Lights_Down_Low_(Max_song)',
#   'https://en.wikipedia.org/wiki/Young_Dumb_%26_Broke',
#   'https://en.wikipedia.org/wiki/One_Kiss_(song)',
#   'https://en.wikipedia.org/wiki/Natural_(Imagine_Dragons_song)',
#   'https://en.wikipedia.org/wiki/You_Make_It_Easy',
#   'https://en.wikipedia.org/wiki/Shape_of_You',
#   'https://en.wikipedia.org/wiki/I_Get_the_Bag',
#   'https://en.wikipedia.org/wiki/No_Brainer_(song)',
#   'https://en.wikipedia.org/wiki/Plain_Jane_(song)',
#   'https://en.wikipedia.org/wiki/Sky_Walker_(song)',
#   'https://en.wikipedia.org/wiki/Marry_Me_(Thomas_Rhett_song)',
#   'https://en.wikipedia.org/wiki/Eastside_(song)',
#   'https://en.wikipedia.org/wiki/Call_Out_My_Name',
#   'https://en.wikipedia.org/wiki/King%27s_Dead',
#   'https://en.wikipedia.org/wiki/Happier_(Marshmello_and_Bastille_song)',
#   'https://en.wikipedia.org/wiki/Te_Bot%C3%A9',
#   'https://en.wikipedia.org/wiki/Simple_(Florida_Georgia_Line_song)',
#   'https://en.wikipedia.org/wiki/Lemon_(N.E.R.D_and_Rihanna_song)',
#   'https://en.wikipedia.org/wiki/1-800-273-8255_(song)',
#   'https://en.wikipedia.org/wiki/Say_Something_(Justin_Timberlake_song)',
#   'https://en.wikipedia.org/wiki/I%27m_Upset',
#   'https://en.wikipedia.org/wiki/Get_Along_(Kenny_Chesney_song)',
#   'https://en.wikipedia.org/wiki/Moonlight_(XXXTentacion_song)',
#   'https://en.wikipedia.org/wiki/What_Lovers_Do',
#   'https://en.wikipedia.org/wiki/X_(Nicky_Jam_and_J_Balvin_song)',
#   'https://en.wikipedia.org/wiki/Outside_Today',
#   'https://en.wikipedia.org/wiki/Trip_(Ella_Mai_song)',
#   'https://en.wikipedia.org/wiki/Dura_(song)',
#   'https://en.wikipedia.org/wiki/Changes_(XXXTentacion_song)',
#   'https://en.wikipedia.org/wiki/Mercy_(Brett_Young_song)',
#   'https://en.wikipedia.org/wiki/One_Number_Away',
#   'https://en.wikipedia.org/wiki/Powerglide_(song)',
#   'https://en.wikipedia.org/wiki/IDGAF_(Dua_Lipa_song)',
#   'https://en.wikipedia.org/wiki/Mi_Gente_(J_Balvin_and_Willy_William_song)',
#   'https://en.wikipedia.org/wiki/Believer_(Imagine_Dragons_song)']}

# %%
#saving 300 songs wikipedia pages of 3 years
def save_html2(url, k):
    response1 = urllib.request.urlopen(url)
    webContent = response1.read()
    
    f = open('./data/300_songs_wiki/'+"201"+str(k)+"_"+name_of_song+'.html', 'wb') #if there is no such file the function open creates it 
    f.write(webContent)
    f.close

    
for i in range (6,9):    
    for url in songs_urls_wiki["201{}".format(i)]:
        temp=str(url).split('/')
        name_of_song=temp[len(temp)-1]
        save_html2(url, i)

# %% [markdown]
# Collecting eachh song XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %%
#get release, genre and producer for each song, via wiki page.
wiki300_dir='./data/300_songs_wiki/'
wiki300_dir_fse = os.fsencode(wiki300_dir)


# ------ test one song ---------
# content = open("./data/300_songs_wiki/2016_2_Phones.html", encoding='utf-8')
# soup_wiki_song = bs(content, "html.parser")

# temp = soup_wiki_song.find("table", {"class": "infobox vevent"})
# kaki=temp.findAll('span', {"class": "bday dtstart published updated"})
# list_of_inner_text = [x.text for x in kaki]
# text = ', '.join(list_of_inner_text)

# print(text)


# ---------- all songs ---------------

for file in os.listdir(wiki300_dir_fse):
    filename = os.fsdecode(file)
    content = open("{}{}".format(wiki300_dir, filename), encoding='utf-8')
    soup_wiki_song = bs(content, "html.parser")
    
    print(filename)
    
    table = soup_wiki_song.find("table", {"class": "infobox vevent"})
    
    # get release info
    t_rel = table.findAll('span', {"class": "bday dtstart published updated"})
    list_of_inner_text = [x.text for x in t_rel]
    text_rel = ', '.join(list_of_inner_text)
    print (text_rel)
    
    # get genre
    t_genre = table.findAll('td', {"class": "category hlist"})
    list_of_inner_text = [x.text for x in t_genre]
    text_genre = ', '.join(list_of_inner_text)
    print (text_genre)
      
    # get producer
    t_producer = table.findAll('td', {"class": "hlist"})
    list_of_inner_text = [x.text for x in t_producer]
    text_producer = ', '.join(list_of_inner_text)
    print (text_producer)
    print("\n")
# Out:
# 2016_2_Phones.html
# 2015-11-05
# Hip hop
# Digital download, Hip hop, BWAAtlantic, Kevin GilyardBrittany Hazzard
#
#
# 2016_679_(song).html
# 2015-06-29
# Hip hop
# Digital download, Hip hop,
# RGF
# 300
# ,
# Willie Maxwell
# Remy Boyz
# ,
# Brian "Peoples" Garcia
# Micah Street
#
#
#
# 2016_7_Years_(Lukas_Graham_song).html
#
# Soul-pop
# Soul-pop, CopenhagenWarner Bros., Lukas ForchammerStefan ForrestMorten RistorpMorten Pilegaard, Future AnimalsPilo
#
#
# 2016_Adventure_of_a_Lifetime.html
#
#
# Pop[1]
# disco[1][2][3]
# funk[1]
#
# Digital download,
# Pop[1]
# disco[1][2][3]
# funk[1]
# ,
# Parlophone
# Atlantic
# ,
# Guy Berryman
# Jonny Buckland
# Will Champion
# Mikkel S. Eriksen
# Tor Erik Hermansen
# Chris Martin
# ,
# Rik Simpson
# Stargate
#
#
#
# 2016_All_In_My_Head_(Flex).html
# 2016-05-31
# Reggae-trap
# Digital download, Reggae-trap, EpicSyco,
# Various
#
#
# Mikkel Eriksen
# Tor Hermansen
# Benjamin Levin
# Willie Maxwell
# Skye Sweetnam
# Daystar Peterson
# Nolan Lambroza
# Julia Cavazos
# Brian Garcia
# Ewart Brown
# Clifton Dillon
# Richard Foulks
# Camila Cabello
# Lauren Jauregui
# Normani Kordei
# Dinah Jane Hansen
# Ally Brooke Hernandez
# Herbert Harris
# Leroy Romans
# Lowell Dunbar
# Brian Thompson
# Handel Tucker
#
# ,
# Stargate
# Brian Garcia
# Victoria Monét (vocal producer)
#
#
#
# 2016_All_the_Way_Up_(Fat_Joe_and_Remy_Ma_song).html
# 2016-03-02
# Hip hop
# Digital download, Hip hop, RNGEmpire,
# Various
# Joseph CartagenaReminisce MackieShawn Carter (remix)Calvin Broadus (Westside remix)Jayceon Taylor (Westside remix)Earl Stevens (Westside remix)Park Jae-beom (Asian remix)Kalassy Nikoff (Asian remix)Mikael Lozach (Asian remix)Johan Ishak (Asian remix)
# , EdsclusiveCool & Dre & Domarj
#
#
# 2016_Antidote_(Travis_Scott_song).html
#
# Hip hoptrapcloud rap
#
# Digital download
# streaming
# , Hip hoptrapcloud rap, Grand HustleEpic, Jacques WebsterEbony OshunrindeThomas BrenneckDavid GuyLeon MichelsNicholas MovshonHomer SteinweissBryan Van Mierlo, WondaGurlEestbound
#
#
# 2016_Back_to_Sleep_(song).html
#
# R&B
# Digital download, R&B, RCA Records,
# Chris Brown
# Anderson Hernandez
# Matthew Samuels
# Allen Ritter
# August Rigo
# ,
# Vinylz
# Boi-1da
# Ritter
#
#
#
# 2016_Broccoli_(D.R.A.M._song).html
#
# Hip hoptrap
# 7"digital download, Hip hoptrap, AtlanticEmpire, Shelley Massenburg-SmithMiles McCollumRogét ChahayedJulian Gramma, J GrammChahayedKarl Rubin
#
#
# 2016_Cake_by_the_Ocean.html
#
#
# Nu-disco[1]
# funk[1]
#
# Digital download,
# Nu-disco[1]
# funk[1]
# , Republic,
# Robin Fredriksson
# Mattias Larsson
# Joe Jonas
# Justin Tranter
# ,
# Mattman & Robin
#
#
#
# 2016_Can%27t_Feel_My_Face.html
# 2015-06-08
# Popdisco-funk
# Digital download, Popdisco-funk, XORepublic, Ali PayamiSavan KotechaMax MartinAbel TesfayePeter Svensson, Max MartinAli Payami
#
#
# 2016_Can%27t_Stop_the_Feeling!.html
# 2016-05-06
# Discopopsoul
# 12-inchCDdigital download, Discopopsoul, RCA, Justin TimberlakeMax MartinJohan Schuster, Justin TimberlakeMax MartinShellback
#
#
# 2016_Cheap_Thrills_(song).html
#
#
# Synthpop
# dancehall
#
# Digital download,
# Synthpop
# dancehall
# ,
# Inertia
# Monkey Puzzle
# RCA
# ,
# Sia Furler
# Greg Kurstin
# Sean Paul Henriques
# , Greg Kurstin
#
#
# 2016_Closer_(The_Chainsmokers_song).html
# 2016-07-29
# Future bass[1][2]pop[3]
# Digital download, Future bass[1][2]pop[3], DisruptorColumbia, Andrew TaggartAshley FrangipaneShaun FrankFrederic KennettIsaac SladeJoe King, The Chainsmokers
#
#
# 2016_Close_(Nick_Jonas_song).html
# 2016-03-25
#
# Digital download, IslandSafehouse,
# Robin Fredriksson
# Mattias Larsson
# Julia Michaels
# Justin Tranter
# Tove Nilsson
# , Mattman & Robin[1]
#
#
# 2016_Cold_Water_(song).html
#
#
#
# Mad Decent
# Def Jam
# ,
# Ed Sheeran
# Benjamin Levin
# Karen Marie Ørsted
# Thomas Pentz
# Justin Bieber
# Jamie Scott
#  Philip Meckseper
# King Henry
# ,
# Major Lazer
# Benny Blanco
# Jr Blender
# King Henry
#
#
#
# 2016_Controlla.html
#
# Dancehall[1][2]
# Digital download, Dancehall[1][2], Young MoneyCash MoneyRepublic, Aubrey GrahamMatthew SamuelsAllen RitterDwayne Chin-QueeStephen McGregorGarfield Riley, Jr.Moses DavisDonald DennisGary JacksonPatrick RobertsAndrew ThomasAndrae
# Hugh Sutherland, Boi-1daSupa Dups (co-prod.)Di Genius (co-prod.)Ritter (co-prod.)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-142-939e52a6999f> in <module>
#      22     filename = os.fsdecode(file)
#      23     content = open("{}{}".format(wiki300_dir, filename), encoding='utf-8')
# ---> 24     soup_wiki_song = bs(content, "html.parser")
#      25
#      26     print(filename)
#
# C:\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     279             self.reset()
#     280             try:
# --> 281                 self._feed()
#     282                 break
#     283             except ParserRejectedMarkup:
#
# C:\Anaconda3\lib\site-packages\bs4\__init__.py in _feed(self)
#     340         self.builder.reset()
#     341
# --> 342         self.builder.feed(self.markup)
#     343         # Close out any unfinished strings and close all the open tags.
#     344         self.endData()
#
# C:\Anaconda3\lib\site-packages\bs4\builder\_htmlparser.py in feed(self, markup)
#     245         parser.soup = self.soup
#     246         try:
# --> 247             parser.feed(markup)
#     248             parser.close()
#     249         except HTMLParseError as e:
#
# C:\Anaconda3\lib\html\parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# C:\Anaconda3\lib\html\parser.py in goahead(self, end)
#     171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
# --> 173                     k = self.parse_endtag(i)
#     174                 elif startswith("<!--", i):
#     175                     k = self.parse_comment(i)
#
# C:\Anaconda3\lib\html\parser.py in parse_endtag(self, i)
#     419                 return gtpos
#     420
# --> 421         self.handle_endtag(elem)
#     422         self.clear_cdata_mode()
#     423         return gtpos
#
# C:\Anaconda3\lib\site-packages\bs4\builder\_htmlparser.py in handle_endtag(self, name, check_already_closed)
#     126             self.already_closed_empty_element.remove(name)
#     127         else:
# --> 128             self.soup.handle_endtag(name)
#     129
#     130     def handle_data(self, data):
#
# C:\Anaconda3\lib\site-packages\bs4\__init__.py in handle_endtag(self, name, nsprefix)
#     539     def handle_endtag(self, name, nsprefix=None):
#     540         #print "End tag: " + name
# --> 541         self.endData()
#     542         self._popToTag(name, nsprefix)
#     543
#
# C:\Anaconda3\lib\site-packages\bs4\__init__.py in endData(self, containerClass)
#     416                 return
#     417
# --> 418             o = containerClass(current_data)
#     419             self.object_was_parsed(o)
#     420
#
# C:\Anaconda3\lib\site-packages\bs4\element.py in __new__(cls, value)
#     719         else:
#     720             u = str.__new__(cls, value, DEFAULT_OUTPUT_ENCODING)
# --> 721         u.setup()
#     722         return u
#     723
#
# C:\Anaconda3\lib\site-packages\bs4\element.py in setup(self, parent, previous_element, next_element, previous_sibling, next_sibling)
#     275
#     276         if (previous_sibling is None
# --> 277             and self.parent is not None and self.parent.contents):
#     278             previous_sibling = self.parent.contents[-1]
#     279
#
# KeyboardInterrupt:

# %%
#TO TAKE OUT THE GENRE OF THE SONG FROM WIKI


#content = open('/Users/alisamakarova/Documents/DS_Project/300_songs_wiki'+"2016"+"_"+songs["2016"][0].replace(" ","_")+'.html', 'wb')
# content=open('/Users/alisamakarova/Documents/DS_Project/300_songs_wiki/2016_Hotline_Bling.html', encoding='utf-8')
# txt=content.read()
# content.close()
# soup=bs(txt,'html.parser')
# print(soup)

# %%
import requests

#THE PART OF Q&A PROCESS:


#the case of & in songs:
name_of_song_for_lyrics=songs["2017"][77].replace("& ","")
name_of_song_for_lyrics=name_of_song_for_lyrics.replace(" ","-")

#the case of featuring:
name=songs["2017"][68]
name=name.replace(" ","-")
list=artists["2017"][68].split('featuring')
#we will always take the first artist
artist_str=list[0]


#the case of and and ':
name=songs["2017"][26].replace("'","")
name=name.replace(" ","-")
list=artists["2017"][26].split('and')
#we will always take the first artist
artist_str=list[0]

#the case of & in artists:
name=songs["2017"][62]
name=name.replace(" ","-")
list=artists["2017"][62].split('&')
#we will always take the first artist
artist_str=list[0]


#the case of , and featuring in artists:
songs["2018"][44]='halsey' #(Him & I different name of the song)
name=songs["2018"][44]
name=name.replace(" ","-")
list=artists["2018"][44].split(',')
#we will always take the first artist
artist_str=list[0]
list=artist_str.split('and')
artist_str=list[0]
list=artist_str.split('featuring')
artist_str=list[0]


url='https://www.metrolyrics.com/'+name+'-lyrics-'+artist_str.replace('"','').replace(" ","-")+'.html'
#the case of "Maroon-5-.html"
url=url.replace("-.",".")                              
print(url)

# %%
#creating the dictionary of urls for each song's lyrics
lyrics_urls={"2016": [],"2017": [], "2018": []}

#handling with the specific cases 
songs["2018"][44]='halsey' 
songs["2018"][83]='18002738255' 
songs["2016"][37]=songs["2016"][37].replace("U","you")
songs["2016"][48]='holy'
artists["2018"][82]='nerd-the-neptunes'

for i in range(6,9):
    for k in range(0,100):
        #the case of & in songs:
        name=songs["201{}".format(i)][k].replace("& ","").replace("'","")
        name=name.replace(" ","-")

        list=artists["201{}".format(i)][k].split(',')
        #we will always take the first artist
        artist_str=list[0]
        list=artist_str.split('and')
        artist_str=list[0]
        list=artist_str.split('featuring')
        artist_str=list[0]

        url='https://www.metrolyrics.com/'+name+'-lyrics-'+artist_str.replace('"','').replace(" ","-")+'.html'
        #the case of "Maroon-5-.html"
        url=url.replace("-.",".") 

        lyrics_urls["201{}".format(i)].append(url)
   
print(len(lyrics_urls["2018"]))

# %%
import time
time.sleep(3)

#the part of creation of the lyrics_texts dictionary which contain the lyrics of each song in top 2016,2017,2018
lyrics_texts={"2016": [],"2017": [], "2018": []}

for i in range(6,9):
    for k in range(0,100):
        url = lyrics_urls["201{}".format(i)][k]
        response = requests.get(url)
        data = response.text
        soup = bs(data,'html.parser')
        try2 = soup.findAll("p",{"class":"verse"})
        temp = ""
        for p in try2:
            temp = str(temp) + str(p.text)
        lyrics_texts["201{}".format(i)].append(temp)

# %%
print(temp)

# %% [markdown]
# # Phase 2 - Learning Algoorithm & Performance Evaluation
